# %% [markdown]
# # Módulo 6 tarefa 1
#
# #### 1) A base 'sinasc_RO_2019.csv' contém dados do sistema de nascidos vivos do DataSUS, cujo dicionário de dados está no arquivo 'Estrutura_SINASC_para_CD.pdf'. Carregue esses arquivos.

# %%
import pandas as pd
import requests
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sinasc = pd.read_csv('SINASC_RO_2019.csv')
sinasc.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...

# %% [markdown]
# ####  2) Monte um gráficos de barras com as variáveis APGAR1, APGAR5, SEXO, GESTACAO, ESTCIVMAE.

# %%
# Os gráficos funcionam dentro da lógica do matplotlib
plt.close('all')
plt.rc('figure', figsize=(12,8))
fig, axes = plt.subplots(2,3)

sns.countplot(ax = axes[0,0], x='APGAR1', data=sinasc).tick_params(axis="x", rotation = 90) #ajustar rotacao do eixo x
sns.countplot(ax = axes[0,1], x='APGAR5', data=sinasc).tick_params(axis="x", rotation = 90)
sns.countplot(ax = axes[0,2], x='SEXO', data=sinasc)
sns.countplot(ax = axes[1,0], x='GESTACAO', data=sinasc).tick_params(axis="x", rotation = 90)
sns.countplot(ax = axes[1,1], x='ESTCIVMAE', data=sinasc)

plt.subplots_adjust(wspace=0.4, hspace=0.3) #ajustar o espaçamento

# %% [markdown]
# #### 3) Monte um gráfico de barras mostrando o APGAR5 médio por CONSULTAS

# %%
plt.close('all')
plt.rc('figure', figsize=(10,8))
# Usando o barplot que traz a média da variável y por padrão
sns.barplot( x='APGAR5', y='CONSULTAS', data=sinasc)
# Out:
# <Axes: xlabel='APGAR5', ylabel='CONSULTAS'>

# %% [markdown]
# ####  4) Monte um painel com 4 gráficos mostrando as frequencias de SEXO, GESTACAO, ESTCIVMAE e CONSULTAS

# %%
plt.close('all')
plt.rc('figure', figsize=(10,10))
fig, axes = plt.subplots(2,2)

sns.countplot(ax = axes[0,0], x='SEXO', data=sinasc)
sns.countplot(ax = axes[0,1], x='GESTACAO', data=sinasc).tick_params(axis="x", rotation = 90)
sns.countplot(ax = axes[1,0], x='ESTCIVMAE', data=sinasc)
sns.countplot(ax = axes[1,1], x='CONSULTAS', data=sinasc)

plt.subplots_adjust(wspace=0.4, hspace=0.8)
